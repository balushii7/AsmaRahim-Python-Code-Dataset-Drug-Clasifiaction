# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D,BatchNormalization
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.models import load_model
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings("ignore")
import pathlib
import PIL
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('drug200 (version 1) (1).csv')
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
df.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
# Let's check the Target_feature , and as we see there is imblance data issue we have to solve first before fitting model on this data we have ; b
plt.figure(figsize = (6,3),dpi = 200)
sns.countplot(data = df , x = 'Drug')
# Out:
# <Axes: xlabel='Drug', ylabel='count'>

# %%
plt.figure(figsize = (8,4),dpi = 200)
sns.scatterplot(data = df , x = 'Age' , y = 'Na_to_K',hue = 'Drug')
# Out:
# <Axes: xlabel='Age', ylabel='Na_to_K'>

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = 'Sex', y = 'Age', hue = 'Drug', data = df)
plt.title("CH vs NA_to_K")
plt.show()

# %%
 drug_count = df['Drug'].value_counts().tolist()

# %%
drug_label = df['Drug'].value_counts().index
drug_label
# Out:
# Index(['DrugY', 'drugX', 'drugA', 'drugC', 'drugB'], dtype='object')

# %%
plt.figure(figsize = (8,4),dpi = 150)
plt.pie(drug_count , labels = drug_label , autopct = '%1.2f%%',textprops={'fontweight':'bold','size' :13},explode = [0.1,0,0,0,0],startangle= 90,
       pctdistance = 0.8 , radius = 2)
plt.show()

# %%
# Divid data to X and y , and also get dummies for all object data 
X = pd.get_dummies(df.drop('Drug', axis = 1), drop_first= True ,prefix_sep = '*')
y = df['Drug']

# %%
from imblearn import over_sampling , under_sampling
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=0)
X_resambled , y_resampled = ros.fit_resample(X,y)

# %%
 ##Now we are going to make train test split to split the data we have to train data and test data 
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resambled, y_resampled, test_size=0.20, random_state=101)

# %%
X_train, X_test, y_train, y_test
# Out:
# (     Age  Na_to_K  Sex*M  BP*LOW  BP*NORMAL  Cholesterol*NORMAL
#  64    60   13.303      0       0          0                   0
#  336   68   10.189      0       0          0                   1
#  139   69   10.065      0       0          1                   0
#  310   70   13.967      1       0          0                   0
#  212   19   13.313      0       0          0                   0
#  ..   ...      ...    ...     ...        ...                 ...
#  63    45    8.370      1       1          0                   1
#  326   53   12.495      0       0          0                   1
#  337   53   12.495      0       0          0                   1
#  11    34   19.199      0       0          0                   1
#  351   56   11.567      0       1          0                   0
#
#  [364 rows x 6 columns],
#       Age  Na_to_K  Sex*M  BP*LOW  BP*NORMAL  Cholesterol*NORMAL
#  12    43   15.376      1       1          0                   0
#  19    32   25.974      0       0          0                   1
#  133   24   25.786      1       0          1                   0
#  211   29   12.856      1       0          0                   0
#  317   74    9.567      1       0          0                   0
#  ..   ...      ...    ...     ...        ...                 ...
#  355   23    7.298      1       1          0                   0
#  391   22    8.151      1       1          0                   0
#  51    67   10.898      1       0          1                   1
#  4     61   18.043      0       1          0                   0
#  425   64    7.761      1       0          1                   0
#
#  [91 rows x 6 columns],
#  64     drugB
#  336    drugB
#  139    drugX
#  310    drugB
#  212    drugA
#         ...
#  63     drugX
#  326    drugB
#  337    drugB
#  11     DrugY
#  351    drugC
#  Name: Drug, Length: 364, dtype: object,
#  12     DrugY
#  19     DrugY
#  133    DrugY
#  211    drugA
#  317    drugB
#         ...
#  355    drugC
#  391    drugC
#  51     drugX
#  4      DrugY
#  425    drugX
#  Name: Drug, Length: 91, dtype: object)

# %%
# !pip install --upgrade scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\asma albalushi\appdata\roaming\python\python310\site-packages (1.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: joblib>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.1.1)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.2.2

# %%
from sklearn.metrics import confusion_matrix 
import matplotlib.pyplot as plt

# %%
test_error_rate = []

for k in range (1,30): 
    knn_model = KNeighborsClassifier(n_neighbors=k)
    knn_model.fit(X_train , y_train)
    y_pred = knn_model.predict(X_test)
    
    test_error = 1 - accuracy_score(y_test , y_pred)
    test_error_rate.append(test_error)

# %%
##Create CNN Model
cnn_model = Sequential ([
    Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(50, 50, 3)),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2), strides=2),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2), strides=2),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D((2, 2), strides=2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10,  activation='softmax')
])

# %%
# Compile the model
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Flatten the output
cnn_model.add(Flatten())

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 50, 50, 32)        896
#
#  conv2d_16 (Conv2D)          (None, 50, 50, 32)        9248
#
#  batch_normalization_2 (Batc  (None, 50, 50, 32)       128
#  hNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 25, 25, 32)       0
#  2D)
#
#  conv2d_17 (Conv2D)          (None, 25, 25, 64)        18496
#
#  conv2d_18 (Conv2D)          (None, 25, 25, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 25, 25, 64)       256
#  hNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv2d_19 (Conv2D)          (None, 12, 12, 64)        36928
#
#  conv2d_20 (Conv2D)          (None, 12, 12, 64)        36928
#
#  max_pooling2d_10 (MaxPoolin  (None, 6, 6, 64)         0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 2304)              0
#
#  dense_7 (Dense)             (None, 128)               295040
#
#  dense_8 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 436,138
# Trainable params: 435,946
# Non-trainable params: 192
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
cnn_model = KNeighborsClassifier(n_neighbors=1)
cnn_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
predictions = model.predict(X_test)
# Out:
# 3/3 [==============================] - 5s 3ms/step

# %%
predictions = model.predict(X_test)
predictions = np.argmax(predictions, axis=1)
# Out:
# 3/3 [==============================] - 6s 4ms/step

# %%
print ("Accuracy = ", metrics.accuracy_score(y_test, predictions))
# Out:
# Accuracy =  0.0

# %%
plt.plot(range(1,30), test_error_rate)
plt.ylabel('Test_error_rate')
plt.xlabel('K Value')
plt.title('Get The Best K Value VS Test_error_Rate')
# Out:
# Text(0.5, 1.0, 'Get The Best K Value VS Test_error_Rate')

# %%
def metrics_needed (model):
    y_pred = model.predict(X_test)
    
    print('/n')
    
    print(classification_report(y_test,y_pred))
    plot_confusion_matrix(model , X_test , y_test)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_model = DecisionTreeClassifier()

# %%
tree_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# !pip install --upgrade scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\asma albalushi\appdata\roaming\python\python310\site-packages (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.23.5)

# %%
from sklearn.metrics import classification_report

# %%
def metrics_needed(model):
    y_pred = model.predict(X_test)
    print('\C')
    print(classification_report(y_test, y_pred))
    plot_confusion_matrix(model, X_test, y_test)

# %%
metrics_needed(knn_model)
# Out:
# \C
#               precision    recall  f1-score   support
#
#        DrugY       1.00      0.65      0.79        20
#        drugA       0.59      0.95      0.73        21
#        drugB       0.50      0.88      0.64        17
#        drugC       0.70      0.44      0.54        16
#        drugX       0.50      0.12      0.19        17
#
#     accuracy                           0.63        91
#    macro avg       0.66      0.61      0.58        91
# weighted avg       0.67      0.63      0.59        91
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[200], line 1
# ----> 1 metrics_needed(knn_model)
#
# Cell In[183], line 5, in metrics_needed(model)
#       3 print('\C')
#       4 print(classification_report(y_test, y_pred))
# ----> 5 plot_confusion_matrix(model, X_test, y_test)
#
# NameError: name 'plot_confusion_matrix' is not defined
